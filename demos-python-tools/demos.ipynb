# %% [markdown]
# **Simple test case**<br>
# succeeds

# %%
# division

# set numerator and denominator
x = 1
y = 1

answer = x / y

print("x / y =", answer)
# Out:
# x / y = 1.0

# %% [markdown]
# **Boundary condition (Edge case)**<br>
# crashes

# %%
# division

# set numerator and denominator
x = 5
y = 0

answer = x / y

print("x / y =", answer)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 5 in <cell line: 7>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=3'>4</a> x = 5
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=4'>5</a> y = 0
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=6'>7</a> answer = x / y
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=8'>9</a> print("x / y =", answer)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **Syntax Error**<br>
# Too many parenthesis between the<br>
# print function and the string

# %%
print(("Print some text")
# Out:
#   Input In [2]
#     print(("Print some text")
#                              ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# **Runtime Error**<br>
# Typo alert!<br>
# The variable set is nyAnswer<br>
# The variable printed is myAnswer

# %%
nyAnswer = 42
print(myAnswer)
# Out:
# hi
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\lkeeley\OneDrive - Pace University\teaching\CS 121 F 23\Modules\4 - Python Tools & Techniques\demos\demos.ipynb Cell 8 line <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/lkeeley/OneDrive%20-%20Pace%20University/teaching/CS%20121%20F%2023/Modules/4%20-%20Python%20Tools%20%26%20Techniques/demos/demos.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> nyAnswer = 42
#       <a href='vscode-notebook-cell:/c%3A/Users/lkeeley/OneDrive%20-%20Pace%20University/teaching/CS%20121%20F%2023/Modules/4%20-%20Python%20Tools%20%26%20Techniques/demos/demos.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> print("hi")
# ...

# %% [markdown]
# **Semantic Error**<br>
# The programmer forgot to assign the result to a variable.<br>
# Sum is a built in function so this program won't crash<br>
# but the result isn't what we expected

# %%
# add two numbers
x = 1
y = 2

x + y

print(sum)
# Out:
# 3

# %%
# this is a comment

# %% [markdown]
# **Turtles**<br>
# Instances, Attributes, Methods

# %%
import turtle

# create an instance of a screen
screen = turtle.Screen()
# screen.exitonclick()
# create an instance of a turtle
t = turtle.Turtle()
# use the color method to set the turtle's color attribute
t.color("red")
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# **for loop**

# %%
# repeat 8 times to draw an octagon
for _ in range(8):
    t.forward(20)
    t.right(45) # 360 / 8 = 45
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import turtle
screen = turtle.Screen()
cali = turtle.Turtle()
cali.color("blue")



cali.forward(50)
cali.backward(-50)
cali.draw(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\lkeeley\OneDrive - Pace University\teaching\IS 612 Sum II 23\Modules\4 - Python Tools & Techniques\demos\demos.ipynb Cell 16 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/c%3A/Users/lkeeley/OneDrive%20-%20Pace%20University/teaching/IS%20612%20Sum%20II%2023/Modules/4%20-%20Python%20Tools%20%26%20Techniques/demos/demos.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a> cali.forward(50)
#       <a href='vscode-notebook-cell:/c%3A/Users/lkeeley/OneDrive%20-%20Pace%20University/teaching/IS%20612%20Sum%20II%2023/Modules/4%20-%20Python%20Tools%20%26%20Techniques/demos/demos.ipynb#X25sZmlsZQ%3D%3D?line=8'>9</a> cali.backward(-50)
# ...

# %%
total = 0
for _ in range(3):
    total += int(input("Enter a number: "))
print("The average is", total / 3)
# Out:
# The average is 1.0
# The average is 2.6666666666666665
# The average is 4.0

# %%
for x in range(7):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(2):
    print(i)
print("Done")
# Out:
# 0
# 1
# Done
